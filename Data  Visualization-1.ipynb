# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([5,7,9,5,3,1])
plt.title("Line plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(x,y)

# %%
y=np.array([5,7,9,5,3,1])
plt.title("Line plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(y)

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([5,7,9,5,3,1])
plt.title("Line plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(x,y,"*:b")

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([5,7,9,5,3,1])
plt.title("Line plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(x,y,linewidth=5,color='y')

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([5,7,9,5,3,1])
plt.title("Line plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.plot(x,y,"*:b")

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([2,4,6,8,10,10])
plt.subplot(1,2,1)
plt.plot(x,y)

x1=np.array([1,2,3,4,5,6])
y1=np.array([5,7,9,11,3,9])
plt.subplot(1,2,2)
plt.plot(x1,y1)

# %%
x=np.array([1,2,3,4,5,6])
y=np.array([2,11,6,3,10,10])
plt.scatter(x,y)
